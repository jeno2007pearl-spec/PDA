# %% [markdown]
# #introdution to python

# %%
print("hello world")
print("welcome to pda")
# Out:
# hello world
# welcome to pda

# %% [markdown]
# #indentation

# %%
print("I heve no indeptation")
print("I heve indeptation")
# Out:
# I heve no indeptation
# I heve indeptation

# %% [markdown]
# #taking input()

# %%
name=input ("Enter your name")
print("hello" , name , "welcome!")
# Out:
# Enter your name jeno
# hello jeno welcome!

# %% [markdown]
# #printing output

# %%
s="ABC"
age=25
p=25
p="india"
print(s,age,p)
# Out:
# ABC 25 india

# %% [markdown]
# #taking multiple input

# %%
x,y,z = input ("Enter three value:").split()
print ("total number of student:",x)
print  ("total number of boys :",y)
print ("total  number of girls:",z)
# Out:
# Enter three value: 30 15 15
# total number of student: 30
# total number of boys : 15
# total  number of girls: 15

# %% [markdown]
# ### python varible

# %%
x = 55.7
s = "hello"
print(x)
print(s)
# Out:
# 55.7
# hello

# %% [markdown]
# #type casting a variable

# %%
i = int(x)
s1= str(x)
print(i)
print(s1)
# Out:
# 55
# 55.7

# %% [markdown]
# #getting type of variable

# %%
n1 = 55
n2 = 55.6
n3 = "hello"
n4 = [1,2,3]
n5 = {"a":1,"b" : 2,"c" :3}
n6 = True
print(type(n1))
print(type(n2))
print(type(n4))
print(type(n5))
print(type(bool))

# %% [markdown]
# #python data types

# %% [markdown]
# #number data types

# %%
a = 5
print(type(a))
b = 5.2
print(type(b))
c = "ball"
print(type(c))

# %% [markdown]
# #sequnce data type

# %%
s = "welcome to pda"
print(type(s))
print(s)
print(s[1])
print(s[-1])

# %% [markdown]
# #list

# %%
a = []
print(type(a))
b =[1,2,3]
print(b)
c = [1,2.3,"A","apple"]
print(c)
print(b[0])
print(b[0])
print(c[-1])
print(c[-2])

# %% [markdown]
# #tuples

# %%
l1 = ("class","for","pda")
l2 = (1,2,3,4,5)
print(type(l1))
print(l2)
print(l1[-1])
print(l2[-2])

# %% [markdown]
# # boolean

# %%
print(type(False))
print(type(True))
if  1:
    print("1 is truth")
else:
    print("0 is false")

# %%
#sets

# %%
s1 = ()
s2 =("Beautiful day")
s3 =set(["A","B","C"])
print(type(s1))
print(s2)
for s in s3:
 print(s,end =" ")

# %%
#Dictionary

# %%
d1={}
d2={"a":1,"b":2,"c":3}
d3={1:"a",2:"b",3:"c"}
print(d2)
print(d3[1])

# %% [markdown]
# #Type conversion

# %%
x=10
y=10.6
z=x+y
print(type(x))
print(type(y))
print(type(z))
